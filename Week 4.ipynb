# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ## IBM Data Science Professional Certificate - Class #9 Applied Data Science Capstone

# %% [markdown]
# ### Yuwei Bao 6/28/2020

# %% [markdown]
# ### Project Title: Find the best cafe within 200 metres near Bourbon street, New Orleans, Louisiana, U.S.

# %% [markdown]
# ### Introduction

# %% [markdown]
# As a person who is moving to New Orleans soon, I decided to choose a project that is personally related.
#
# This project will provide visitors the suggustion for a nearby cafe to grab food before they head to Bourbon street, which is the most famous bar street in French Quater.
#
# This is a really basic project based on the technics. However, for anyone visits a city for the first time and for a short stay, having a recommended cafe will help increase the quality of the visiting.

# %% [markdown]
# ### Data and References

# %% [markdown]
# Data:
#
# - Address data for Bourbon street https://www.mapquest.com/us/louisiana/bourbon-street-265728386, which is used to get the latitude and longitude data.
# - Bourbon Street's latitude and longitude coordinates, which is used to get the venue data and to plot the map
#
# References:
#
# - Week 3: Foursquare API lab, which can be downloade at http://cocl.us/DP0701EN_Coursera_Week2_Notebook1

# %% [markdown]
# ### Methodology

# %% [markdown]
# Foursquare was used to provide the atitude, longitude, name, address, distance, and rating data of the cafe.
#
# This project processes the rating data, visulizes locations on map, and makes analysis to provide visiters a short report to help they make their decisions.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
# This part is the information about my CLEINT_ID, CLIENT_SECRET and other private information. I have removed it for my privacy.

# %% [markdown]
# ## Before went to the bar at Bourbon street, tourists may want to grab some food

# %% [markdown]
# ### Converting the Bourbon street's address to its latitude and longitude coordinates
# Address data was obtained from https://www.mapquest.com/us/louisiana/bourbon-street-265728386

# %%
address = '700 Bourbon St., New Orleans, LA'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 29.9586069 -90.0654573

# %% [markdown]
# ### Search for cafe that is within 200 metres from Bourbon street

# %%
search_query = 'cafe'
radius = 300
print('Searching for '+ search_query)
# Out:
# Searching for cafe

# %%
# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5PM0YDTXEDFRWVXI5HYXDU3HL3HVYTYFXU045ESX51MEJ2N3&client_secret=0E55LKYOM31UJQVZV4VJATAGWTNBOQEAQC4E0NSK5R1NO0JH&ll=29.9586069,-90.0654573&v=20180604&query=cafe&radius=300&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ef91e8ee0d74740ce0812a0'},
#  'response': {'venues': [{'id': '4aa59477f964a520dd4820e3',
#     'name': 'Café du Monde',
#     'location': {'address': '800 Decatur St',
#      'crossStreet': 'at The French Market',
#      'lat': 29.957509521972145,
#      'lng': -90.06205604352482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.957509521972145,
#        'lng': -90.06205604352482}],
#      'distance': 350,
#      'postalCode': '70116',
#      'cc': 'US',
#      'neighborhood': 'French Quarter',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['800 Decatur St (at The French Market)',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4b7648f6f964a520a8462ee3',
#     'name': 'Cafe Lafitte In Exile',
#     'location': {'address': '901 Bourbon St',
#      'crossStreet': 'at Dumaine St.',
#      'lat': 29.960307833901943,
#      'lng': -90.06411960770991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.960307833901943,
#        'lng': -90.06411960770991}],
#      'distance': 229,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['901 Bourbon St (at Dumaine St.)',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d8941735',
#       'name': 'Gay Bar',
#       'pluralName': 'Gay Bars',
#       'shortName': 'Gay Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '48898359'},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4aecf62ef964a52076cc21e3',
#     'name': 'Cafe Maspero',
#     'location': {'address': '601 Decatur St',
#      'crossStreet': 'at Toulouse St',
#      'lat': 29.956004680661643,
#      'lng': -90.0634610652136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.956004680661643,
#        'lng': -90.0634610652136},
#       {'label': 'entrance', 'lat': 29.956032, 'lng': -90.063513}],
#      'distance': 347,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['601 Decatur St (at Toulouse St)',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17a941735',
#       'name': 'Cajun / Creole Restaurant',
#       'pluralName': 'Cajun / Creole Restaurants',
#       'shortName': 'Cajun / Creole',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1334504',
#      'url': 'https://www.grubhub.com/restaurant/cafe-maspero-601-decatur-street-new-orleans/1334504?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1334504',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '48167065'},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4ad4c04df964a52072f320e3',
#     'name': 'Cafe Beignet',
#     'location': {'address': '334 Royal St Ste B',
#      'crossStreet': 'btwn Conti St & Bienville St',
#      'lat': 29.955332800477585,
#      'lng': -90.06712001610941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.955332800477585,
#        'lng': -90.06712001610941}],
#      'distance': 398,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['334 Royal St Ste B (btwn Conti St & Bienville St)',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1493985',
#      'url': 'https://www.grubhub.com/restaurant/cafe-beignet-334-royal-street-new-orleans/1493985?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1493985',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4aeb317af964a5207abf21e3',
#     'name': "Tony Seville's Pirates Alley Cafe & Old Absinthe House",
#     'location': {'address': '622 Pirates Aly',
#      'crossStreet': 'Cabildo Alley',
#      'lat': 29.958027880391437,
#      'lng': -90.06413289591308,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.958027880391437,
#        'lng': -90.06413289591308}],
#      'distance': 143,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['622 Pirates Aly (Cabildo Alley)',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4b2e6845f964a5209fdf24e3',
#     'name': 'Cafe Pontalba',
#     'location': {'address': '546 Saint Peter St',
#      'crossStreet': 'at Chartres St.',
#      'lat': 29.957258,
#      'lng': -90.063818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.957258,
#        'lng': -90.063818},
#       {'label': 'entrance', 'lat': 29.957294, 'lng': -90.063841}],
#      'distance': 218,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['546 Saint Peter St (at Chartres St.)',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17a941735',
#       'name': 'Cajun / Creole Restaurant',
#       'pluralName': 'Cajun / Creole Restaurants',
#       'shortName': 'Cajun / Creole',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1493868',
#      'url': 'https://www.grubhub.com/restaurant/cafe-pontalba-546-saint-peter-new-orleans/1493868?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1493868',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4ef3f22b754a89ace0027eb6',
#     'name': 'Cafe Soule and The Paris Room',
#     'location': {'address': '720 Saint Louis St',
#      'crossStreet': 'Bourbon & Royal',
#      'lat': 29.956736055983352,
#      'lng': -90.06662555497041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.956736055983352,
#        'lng': -90.06662555497041}],
#      'distance': 236,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['720 Saint Louis St (Bourbon & Royal)',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17a941735',
#       'name': 'Cajun / Creole Restaurant',
#       'pluralName': 'Cajun / Creole Restaurants',
#       'shortName': 'Cajun / Creole',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1496863',
#      'url': 'https://www.grubhub.com/restaurant/maison-soule-720-saint-louis-street-new-orleans/1496863?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1496863',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '48611826'},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4bae2d4ff964a5200b8e3be3',
#     'name': 'Cafe Du Monde: Wholesale',
#     'location': {'address': '1039 Decatur St',
#      'lat': 29.95751655637996,
#      'lng': -90.0618350427672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.95751655637996,
#        'lng': -90.0618350427672}],
#      'distance': 369,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['1039 Decatur St',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5e50195087d44900083aa068',
#     'name': 'Cafe Beignet at the Old Coffee Pot',
#     'location': {'address': '714 Saint Peter St',
#      'lat': 29.958095,
#      'lng': -90.065028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.958095,
#        'lng': -90.065028},
#       {'label': 'entrance', 'lat': 29.958195, 'lng': -90.065133}],
#      'distance': 70,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['714 Saint Peter St',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1776785',
#      'url': 'https://www.grubhub.com/restaurant/cafe-beignet-714-saint-peter-new-orleans/1776785?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1776785',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4e7601a4d22d80eb33729adf',
#     'name': 'Vacherie Cafe',
#     'location': {'address': '827 Toulouse St',
#      'crossStreet': 'at Dauphine St.',
#      'lat': 29.958414666734285,
#      'lng': -90.06706590394282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.958414666734285,
#        'lng': -90.06706590394282}],
#      'distance': 156,
#      'postalCode': '70112',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['827 Toulouse St (at Dauphine St.)',
#       'New Orleans, LA 70112',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1493851',
#      'url': 'https://www.grubhub.com/restaurant/vacherie-827-toulouse-street-new-orleans/1493851?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1493851',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5929fd54cad1b65730cc0d9d',
#     'name': 'Cafe Beignet',
#     'location': {'address': '600 Decatur St',
#      'lat': 29.955891090233155,
#      'lng': -90.0634303014444,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.955891090233155,
#        'lng': -90.0634303014444}],
#      'distance': 360,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['600 Decatur St',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1494318',
#      'url': 'https://www.grubhub.com/restaurant/cafe-beignet-600-decatur-st-new-orleans/1494318?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1494318',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4f32433619836c91c7c643c6',
#     'name': 'Internet Cafe On Toulouse',
#     'location': {'address': '717 Toulouse St',
#      'lat': 29.95791,
#      'lng': -90.065562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.95791,
#        'lng': -90.065562}],
#      'distance': 78,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['717 Toulouse St',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4ad4c04ff964a5204ef420e3',
#     'name': 'Café Amelie',
#     'location': {'address': '912 Royal St',
#      'lat': 29.959790900775506,
#      'lng': -90.06287672409657,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.959790900775506,
#        'lng': -90.06287672409657},
#       {'label': 'entrance', 'lat': 29.959675, 'lng': -90.062735}],
#      'distance': 281,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['912 Royal St',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17a941735',
#       'name': 'Cajun / Creole Restaurant',
#       'pluralName': 'Cajun / Creole Restaurants',
#       'shortName': 'Cajun / Creole',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '62596308'},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5506c5a6498e18fb132e132f',
#     'name': 'Cafe Opera',
#     'location': {'address': '541 Bourbon St',
#      'lat': 29.957801818847656,
#      'lng': -90.06689453125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.957801818847656,
#        'lng': -90.06689453125}],
#      'distance': 165,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['541 Bourbon St',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1776494',
#      'url': 'https://www.grubhub.com/restaurant/cafe-opera-541-bourbon-street-new-orleans/1776494?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1776494',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5b5274aacabcff002cd0ad56',
#     'name': 'Cane Cafe',
#     'location': {'lat': 29.957485,
#      'lng': -90.065975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.957485,
#        'lng': -90.065975}],
#      'distance': 134,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['New Orleans, LA 70130', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '50bb94b9e4b0802eba1b140d',
#     'name': 'Cafè Dauphine',
#     'location': {'lat': 29.960599,
#      'lng': -90.065683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.960599,
#        'lng': -90.065683}],
#      'distance': 222,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['New Orleans, LA 70116', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17a941735',
#       'name': 'Cajun / Creole Restaurant',
#       'pluralName': 'Cajun / Creole Restaurants',
#       'shortName': 'Cajun / Creole',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '565a245c498e2fa77238b797',
#     'name': "Cafe A'du Ma",
#     'location': {'lat': 29.95826530456543,
#      'lng': -90.06311798095703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.95826530456543,
#        'lng': -90.06311798095703}],
#      'distance': 228,
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['New Orleans, LA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5ce2974e7b385f002cef512e',
#     'name': 'Café Lifette In Exile',
#     'location': {'address': '901 Bourbon St',
#      'lat': 29.96037,
#      'lng': -90.064198,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.96037,
#        'lng': -90.064198}],
#      'distance': 230,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['901 Bourbon St',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d8941735',
#       'name': 'Gay Bar',
#       'pluralName': 'Gay Bars',
#       'shortName': 'Gay Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4ccf428f3bd6236aef748421',
#     'name': 'Internet Café',
#     'location': {'address': '717 Toulouse St',
#      'lat': 29.957270715855433,
#      'lng': -90.06571044994556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.957270715855433,
#        'lng': -90.06571044994556}],
#      'distance': 150,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['717 Toulouse St',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f0941735',
#       'name': 'Internet Cafe',
#       'pluralName': 'Internet Cafes',
#       'shortName': 'Internet Cafe',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/internetcafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4f8a53f1e4b005979f1eed25',
#     'name': 'Cafe Iguana',
#     'location': {'address': '908 Bourbon St, New Orleans, LA 70116',
#      'lat': 29.9603328704834,
#      'lng': -90.06378936767578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.9603328704834,
#        'lng': -90.06378936767578}],
#      'distance': 250,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['908 Bourbon St, New Orleans, LA 70116',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4bd89e9151170f4768e033e4',
#     'name': 'Cafe Du Monde Gift Shop',
#     'location': {'address': '813 Decatur St',
#      'lat': 29.9577785059062,
#      'lng': -90.06187499240305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.9577785059062,
#        'lng': -90.06187499240305},
#       {'label': 'entrance', 'lat': 29.957894, 'lng': -90.06187}],
#      'distance': 357,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['813 Decatur St',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4efa375d9911b01dddf33d5a',
#     'name': "Fiorella's Cafe",
#     'location': {'lat': 29.959625151923436,
#      'lng': -90.06409579077818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.959625151923436,
#        'lng': -90.06409579077818}],
#      'distance': 173,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['New Orleans, LA 70116', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4f3217ff19836c91c7b52a17',
#     'name': 'Cafe Beignet',
#     'location': {'address': '819 Decatur St',
#      'lat': 29.958036422729492,
#      'lng': -90.0618896484375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.958036422729492,
#        'lng': -90.0618896484375}],
#      'distance': 349,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['819 Decatur St',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5302772a498eb25e961bf139',
#     'name': 'Arrow Cafe',
#     'location': {'address': '628 N Rampart St',
#      'crossStreet': 'Saint Peter Street',
#      'lat': 29.960118,
#      'lng': -90.068558,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.960118,
#        'lng': -90.068558}],
#      'distance': 343,
#      'postalCode': '70112',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['628 N Rampart St (Saint Peter Street)',
#       'New Orleans, LA 70112',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1775692',
#      'url': 'https://www.grubhub.com/restaurant/arrow-cafe-628-n-rampart-st-new-orleans/1775692?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1775692',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '85309908'},
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4e114f39b61c637b97ac9e2e',
#     'name': 'Shawns Corner Cafe Lafitte "In Exile"',
#     'location': {'address': '901 Bourbon St',
#      'crossStreet': 'Dumaine st.',
#      'lat': 29.960359573364258,
#      'lng': -90.06419372558594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.960359573364258,
#        'lng': -90.06419372558594}],
#      'distance': 230,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['901 Bourbon St (Dumaine st.)',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5c68693fb25fee002cd3b846',
#     'name': 'La Cafe',
#     'location': {'address': 'bourbon St',
#      'crossStreet': 'dumaign',
#      'lat': 29.960173,
#      'lng': -90.06415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.960173,
#        'lng': -90.06415}],
#      'distance': 215,
#      'postalCode': '70116',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['bourbon St (dumaign)',
#       'New Orleans, LA 70116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '518e7a67498e6bd4c9d584a9',
#     'name': 'Royal Beignet Cafe',
#     'location': {'lat': 29.956426,
#      'lng': -90.065148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.956426,
#        'lng': -90.065148}],
#      'distance': 244,
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['New Orleans, LA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4cec6679d7cc6a31ff52d3b7',
#     'name': 'Holy Smokes Cafe',
#     'location': {'address': '533 Saint Louis St',
#      'lat': 29.955669403076172,
#      'lng': -90.06488800048828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.955669403076172,
#        'lng': -90.06488800048828}],
#      'distance': 331,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['533 Saint Louis St',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d123951735',
#       'name': 'Smoke Shop',
#       'pluralName': 'Smoke Shops',
#       'shortName': 'Smoke Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '5582f995498e46d4d3502676',
#     'name': '9 Roses Cafe',
#     'location': {'address': '620 Conti St',
#      'lat': 29.955385413786992,
#      'lng': -90.06641580560385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.955385413786992,
#        'lng': -90.06641580560385}],
#      'distance': 370,
#      'postalCode': '70130',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['620 Conti St',
#       'New Orleans, LA 70130',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False},
#    {'id': '4f639794e4b0777dfb9086d9',
#     'name': 'cafedumonde',
#     'location': {'lat': 29.957998530350302,
#      'lng': -90.06686903255383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.957998530350302,
#        'lng': -90.06686903255383}],
#      'distance': 152,
#      'cc': 'US',
#      'state': 'Louisiana',
#      'country': 'United States',
#      'formattedAddress': ['Louisiana', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593384984',
#     'hasPerk': False}]}}

# %%
# Get relevant part of JSON and transform it into a pandas dataframe

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
# 1  [{'id': '4bf58dd8d48988d1d8941735', 'name': 'G...         NaN
# 2  [{'id': '4bf58dd8d48988d17a941735', 'name': 'C...     1334504
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...     1493985
# 4  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...         NaN
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1                                      NaN
# 2  /delivery_provider_grubhub_20180129.png
# 3  /delivery_provider_grubhub_20180129.png
# 4                                      NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 4                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                grubhub  https://www.grubhub.com/restaurant/cafe-masper...
# 3                grubhub  https://www.grubhub.com/restaurant/cafe-beigne...
# 4                    NaN                                                NaN
#
#    hasPerk                        id    location.address  ...  \
# 0    False  4aa59477f964a520dd4820e3      800 Decatur St  ...
# 1    False  4b7648f6f964a520a8462ee3      901 Bourbon St  ...
# 2    False  4aecf62ef964a52076cc21e3      601 Decatur St  ...
# 3    False  4ad4c04df964a52072f320e3  334 Royal St Ste B  ...
# 4    False  4aeb317af964a5207abf21e3     622 Pirates Aly  ...
#
#                            location.formattedAddress  \
# 0  [800 Decatur St (at The French Market), New Or...
# 1  [901 Bourbon St (at Dumaine St.), New Orleans,...
# 2  [601 Decatur St (at Toulouse St), New Orleans,...
# 3  [334 Royal St Ste B (btwn Conti St & Bienville...
# 4  [622 Pirates Aly (Cabildo Alley), New Orleans,...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 29.95750952197214...    29.957510
# 1  [{'label': 'display', 'lat': 29.96030783390194...    29.960308
# 2  [{'label': 'display', 'lat': 29.95600468066164...    29.956005
# 3  [{'label': 'display', 'lat': 29.95533280047758...    29.955333
# 4  [{'label': 'display', 'lat': 29.95802788039143...    29.958028
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0   -90.062056         French Quarter               70116             LA
# 1   -90.064120                    NaN               70116             LA
# 2   -90.063461                    NaN               70130             LA
# 3   -90.067120                    NaN               70130             LA
# 4   -90.064133                    NaN               70116             LA
#
#                                                 name    referralId  \
# 0                                      Café du Monde  v-1593384984
# 1                              Cafe Lafitte In Exile  v-1593384984
# 2                                       Cafe Maspero  v-1593384984
# 3                                       Cafe Beignet  v-1593384984
# 4  Tony Seville's Pirates Alley Cafe & Old Absint...  v-1593384984
#
#   venuePage.id
# 0          NaN
# 1     48898359
# 2     48167065
# 3          NaN
# 4          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                                  name  \
# 0                                       Café du Monde
# 1                               Cafe Lafitte In Exile
# 2                                        Cafe Maspero
# 3                                        Cafe Beignet
# 4   Tony Seville's Pirates Alley Cafe & Old Absint...
# 5                                       Cafe Pontalba
# 6                       Cafe Soule and The Paris Room
# 7                            Cafe Du Monde: Wholesale
# 8                  Cafe Beignet at the Old Coffee Pot
# 9                                       Vacherie Cafe
# 10                                       Cafe Beignet
# 11                          Internet Cafe On Toulouse
# 12                                        Café Amelie
# 13                                         Cafe Opera
# 14                                          Cane Cafe
# 15                                      Cafè Dauphine
# 16                                       Cafe A'du Ma
# 17                              Café Lifette In Exile
# 18                                      Internet Café
# 19                                        Cafe Iguana
# 20                            Cafe Du Monde Gift Shop
# 21                                    Fiorella's Cafe
# 22                                       Cafe Beignet
# 23                                         Arrow Cafe
# 24              Shawns Corner Cafe Lafitte "In Exile"
# 25                                            La Cafe
# 26                                 Royal Beignet Cafe
# 27                                   Holy Smokes Cafe
# 28                                       9 Roses Cafe
# 29                                        cafedumonde
#
#                    categories                                address  cc  \
# 0                        Café                         800 Decatur St  US
# 1                     Gay Bar                         901 Bourbon St  US
# 2   Cajun / Creole Restaurant                         601 Decatur St  US
# 3                        Café                     334 Royal St Ste B  US
# 4                         Bar                        622 Pirates Aly  US
# 5   Cajun / Creole Restaurant                     546 Saint Peter St  US
# 6   Cajun / Creole Restaurant                     720 Saint Louis St  US
# 7                   Gift Shop                        1039 Decatur St  US
# 8                        Café                     714 Saint Peter St  US
# 9                        Café                        827 Toulouse St  US
# 10                       Café                         600 Decatur St  US
# 11                       Food                        717 Toulouse St  US
# 12  Cajun / Creole Restaurant                           912 Royal St  US
# 13                 Restaurant                         541 Bourbon St  US
# 14               Cocktail Bar                                    NaN  US
# 15  Cajun / Creole Restaurant                                    NaN  US
# 16                       Café                                    NaN  US
# 17                    Gay Bar                         901 Bourbon St  US
# 18              Internet Cafe                        717 Toulouse St  US
# 19                  BBQ Joint  908 Bourbon St, New Orleans, LA 70116  US
# 20                  Gift Shop                         813 Decatur St  US
# 21                       Café                                    NaN  US
# 22                       Café                         819 Decatur St  US
# 23                Coffee Shop                       628 N Rampart St  US
# 24                        Bar                         901 Bourbon St  US
# 25                        Bar                             bourbon St  US
# 26                       Café                                    NaN  US
# 27                 Smoke Shop                     533 Saint Louis St  US
# 28      Vietnamese Restaurant                           620 Conti St  US
# 29                       Café                                    NaN  US
#
#            city        country                   crossStreet  distance  \
# 0   New Orleans  United States          at The French Market       350
# 1   New Orleans  United States                at Dumaine St.       229
# 2   New Orleans  United States                at Toulouse St       347
# 3   New Orleans  United States  btwn Conti St & Bienville St       398
# 4   New Orleans  United States                 Cabildo Alley       143
# 5   New Orleans  United States               at Chartres St.       218
# 6   New Orleans  United States               Bourbon & Royal       236
# 7   New Orleans  United States                           NaN       369
# 8   New Orleans  United States                           NaN        70
# 9   New Orleans  United States               at Dauphine St.       156
# 10  New Orleans  United States                           NaN       360
# 11  New Orleans  United States                           NaN        78
# 12  New Orleans  United States                           NaN       281
# 13  New Orleans  United States                           NaN       165
# 14  New Orleans  United States                           NaN       134
# 15  New Orleans  United States                           NaN       222
# 16  New Orleans  United States                           NaN       228
# 17  New Orleans  United States                           NaN       230
# 18  New Orleans  United States                           NaN       150
# 19  New Orleans  United States                           NaN       250
# 20  New Orleans  United States                           NaN       357
# 21  New Orleans  United States                           NaN       173
# 22  New Orleans  United States                           NaN       349
# 23  New Orleans  United States            Saint Peter Street       343
# 24  New Orleans  United States                   Dumaine st.       230
# 25  New Orleans  United States                       dumaign       215
# 26  New Orleans  United States                           NaN       244
# 27  New Orleans  United States                           NaN       331
# 28  New Orleans  United States                           NaN       370
# 29          NaN  United States                           NaN       152
#
#                                      formattedAddress  \
# 0   [800 Decatur St (at The French Market), New Or...
# 1   [901 Bourbon St (at Dumaine St.), New Orleans,...
# 2   [601 Decatur St (at Toulouse St), New Orleans,...
# 3   [334 Royal St Ste B (btwn Conti St & Bienville...
# 4   [622 Pirates Aly (Cabildo Alley), New Orleans,...
# 5   [546 Saint Peter St (at Chartres St.), New Orl...
# 6   [720 Saint Louis St (Bourbon & Royal), New Orl...
# 7   [1039 Decatur St, New Orleans, LA 70116, Unite...
# 8   [714 Saint Peter St, New Orleans, LA 70116, Un...
# 9   [827 Toulouse St (at Dauphine St.), New Orlean...
# 10  [600 Decatur St, New Orleans, LA 70130, United...
# 11  [717 Toulouse St, New Orleans, LA 70130, Unite...
# 12  [912 Royal St, New Orleans, LA 70116, United S...
# 13  [541 Bourbon St, New Orleans, LA 70130, United...
# 14             [New Orleans, LA 70130, United States]
# 15             [New Orleans, LA 70116, United States]
# 16                   [New Orleans, LA, United States]
# 17  [901 Bourbon St, New Orleans, LA 70116, United...
# 18  [717 Toulouse St, New Orleans, LA 70130, Unite...
# 19  [908 Bourbon St, New Orleans, LA 70116, New Or...
# 20  [813 Decatur St, New Orleans, LA 70116, United...
# 21             [New Orleans, LA 70116, United States]
# 22  [819 Decatur St, New Orleans, LA 70116, United...
# 23  [628 N Rampart St (Saint Peter Street), New Or...
# 24  [901 Bourbon St (Dumaine st.), New Orleans, LA...
# 25  [bourbon St (dumaign), New Orleans, LA 70116, ...
# 26                   [New Orleans, LA, United States]
# 27  [533 Saint Louis St, New Orleans, LA 70130, Un...
# 28  [620 Conti St, New Orleans, LA 70130, United S...
# 29                         [Louisiana, United States]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 29.95750952197214...  29.957510 -90.062056
# 1   [{'label': 'display', 'lat': 29.96030783390194...  29.960308 -90.064120
# 2   [{'label': 'display', 'lat': 29.95600468066164...  29.956005 -90.063461
# 3   [{'label': 'display', 'lat': 29.95533280047758...  29.955333 -90.067120
# 4   [{'label': 'display', 'lat': 29.95802788039143...  29.958028 -90.064133
# 5   [{'label': 'display', 'lat': 29.957258, 'lng':...  29.957258 -90.063818
# 6   [{'label': 'display', 'lat': 29.95673605598335...  29.956736 -90.066626
# 7   [{'label': 'display', 'lat': 29.95751655637996...  29.957517 -90.061835
# 8   [{'label': 'display', 'lat': 29.958095, 'lng':...  29.958095 -90.065028
# 9   [{'label': 'display', 'lat': 29.95841466673428...  29.958415 -90.067066
# 10  [{'label': 'display', 'lat': 29.95589109023315...  29.955891 -90.063430
# 11  [{'label': 'display', 'lat': 29.95791, 'lng': ...  29.957910 -90.065562
# 12  [{'label': 'display', 'lat': 29.95979090077550...  29.959791 -90.062877
# 13  [{'label': 'display', 'lat': 29.95780181884765...  29.957802 -90.066895
# 14  [{'label': 'display', 'lat': 29.957485, 'lng':...  29.957485 -90.065975
# 15  [{'label': 'display', 'lat': 29.960599, 'lng':...  29.960599 -90.065683
# 16  [{'label': 'display', 'lat': 29.95826530456543...  29.958265 -90.063118
# 17  [{'label': 'display', 'lat': 29.96037, 'lng': ...  29.960370 -90.064198
# 18  [{'label': 'display', 'lat': 29.95727071585543...  29.957271 -90.065710
# 19  [{'label': 'display', 'lat': 29.9603328704834,...  29.960333 -90.063789
# 20  [{'label': 'display', 'lat': 29.9577785059062,...  29.957779 -90.061875
# 21  [{'label': 'display', 'lat': 29.95962515192343...  29.959625 -90.064096
# 22  [{'label': 'display', 'lat': 29.95803642272949...  29.958036 -90.061890
# 23  [{'label': 'display', 'lat': 29.960118, 'lng':...  29.960118 -90.068558
# 24  [{'label': 'display', 'lat': 29.96035957336425...  29.960360 -90.064194
# 25  [{'label': 'display', 'lat': 29.960173, 'lng':...  29.960173 -90.064150
# 26  [{'label': 'display', 'lat': 29.956426, 'lng':...  29.956426 -90.065148
# 27  [{'label': 'display', 'lat': 29.95566940307617...  29.955669 -90.064888
# 28  [{'label': 'display', 'lat': 29.95538541378699...  29.955385 -90.066416
# 29  [{'label': 'display', 'lat': 29.95799853035030...  29.957999 -90.066869
#
#       neighborhood postalCode      state                        id
# 0   French Quarter      70116         LA  4aa59477f964a520dd4820e3
# 1              NaN      70116         LA  4b7648f6f964a520a8462ee3
# 2              NaN      70130         LA  4aecf62ef964a52076cc21e3
# 3              NaN      70130         LA  4ad4c04df964a52072f320e3
# 4              NaN      70116         LA  4aeb317af964a5207abf21e3
# 5              NaN      70116         LA  4b2e6845f964a5209fdf24e3
# 6              NaN      70130         LA  4ef3f22b754a89ace0027eb6
# 7              NaN      70116         LA  4bae2d4ff964a5200b8e3be3
# 8              NaN      70116         LA  5e50195087d44900083aa068
# 9              NaN      70112         LA  4e7601a4d22d80eb33729adf
# 10             NaN      70130         LA  5929fd54cad1b65730cc0d9d
# 11             NaN      70130         LA  4f32433619836c91c7c643c6
# 12             NaN      70116         LA  4ad4c04ff964a5204ef420e3
# 13             NaN      70130         LA  5506c5a6498e18fb132e132f
# 14             NaN      70130         LA  5b5274aacabcff002cd0ad56
# 15             NaN      70116         LA  50bb94b9e4b0802eba1b140d
# 16             NaN        NaN         LA  565a245c498e2fa77238b797
# 17             NaN      70116         LA  5ce2974e7b385f002cef512e
# 18             NaN      70130         LA  4ccf428f3bd6236aef748421
# 19             NaN      70116         LA  4f8a53f1e4b005979f1eed25
# 20             NaN      70116         LA  4bd89e9151170f4768e033e4
# 21             NaN      70116         LA  4efa375d9911b01dddf33d5a
# 22             NaN      70116         LA  4f3217ff19836c91c7b52a17
# 23             NaN      70112         LA  5302772a498eb25e961bf139
# 24             NaN      70116         LA  4e114f39b61c637b97ac9e2e
# 25             NaN      70116         LA  5c68693fb25fee002cd3b846
# 26             NaN        NaN         LA  518e7a67498e6bd4c9d584a9
# 27             NaN      70130         LA  4cec6679d7cc6a31ff52d3b7
# 28             NaN      70130         LA  5582f995498e46d4d3502676
# 29             NaN        NaN  Louisiana  4f639794e4b0777dfb9086d9

# %%
# Just gonna save these results to a csv file for backup
dataframe_filtered.to_csv('cafe_200_near_BourbonStreet_data')

# %%
# Output just the names of these cafe
dataframe_filtered.name
# Out:
# 0     Tony Seville's Pirates Alley Cafe & Old Absint...
# 1                         Cafe Soule and The Paris Room
# 2                    Cafe Beignet at the Old Coffee Pot
# 3                                         Vacherie Cafe
# 4                             Internet Cafe On Toulouse
# 5                                            Cafe Opera
# 6                                             Cane Cafe
# 7                                         Cafè Dauphine
# 8                                          Cafe A'du Ma
# 9                                         Internet Café
# 10                                      Fiorella's Cafe
# 11                                              La Cafe
# 12                                          cafedumonde
# 13                                        Jazz "N" Jazz
# Name: name, dtype: object

# %% [markdown]
# ### Visualize these cafes that are nearby

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=17) # generate map centred around Bourbon Street

# add a red circle marker to represent the Bourbon Street
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Bourbon Street',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the cafes as black circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='black',
        popup=label,
        fill = True,
        fill_color='black',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Explore a Given Venue

# %% [markdown]
# #### 1. Start with the closest cafe -- Cafe Beignet at the Old Coffee Pot (70 metres) to get the venue's overall rating

# %%
venue_id = '5e50195087d44900083aa068'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5e50195087d44900083aa068?client_id=5PM0YDTXEDFRWVXI5HYXDU3HL3HVYTYFXU045ESX51MEJ2N3&client_secret=0E55LKYOM31UJQVZV4VJATAGWTNBOQEAQC4E0NSK5R1NO0JH&v=20180604'

# %%
# Send GET request for result
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'delivery', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '5e50195087d44900083aa068',
#  'name': 'Cafe Beignet at the Old Coffee Pot',
#  'contact': {'phone': '5045004370', 'formattedPhone': '(504) 500-4370'},
#  'location': {'address': '714 Saint Peter St',
#   'lat': 29.958095,
#   'lng': -90.065028,
#   'labeledLatLngs': [{'label': 'display', 'lat': 29.958095, 'lng': -90.065028},
#    {'label': 'entrance', 'lat': 29.958195, 'lng': -90.065133}],
#   'postalCode': '70116',
#   'cc': 'US',
#   'city': 'New Orleans',
#   'state': 'LA',
#   'country': 'United States',
#   'formattedAddress': ['714 Saint Peter St',
#    'New Orleans, LA 70116',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/cafe-beignet-at-the-old-coffee-pot/5e50195087d44900083aa068',
#  'categories': [{'id': '4bf58dd8d48988d16d941735',
#    'name': 'Café',
#    'pluralName': 'Cafés',
#    'shortName': 'Café',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'likes': {'count': 0, 'groups': []},
#  'dislike': False,
#  'ok': False,
#  'delivery': {'id': '1776785',
#   'url': 'https://www.grubhub.com/restaurant/cafe-beignet-714-saint-peter-new-orleans/1776785?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1776785',
#   'provider': {'name': 'grubhub',
#    'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50],
#     'name': '/delivery_provider_grubhub_20180129.png'}}},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1,
#     'items': [{'id': '5e6fd42412e6b900087713bf',
#       'createdAt': 1584387108,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/4090645_dECXEUO1yWMsSdx5a68hQAAUBChMN8pBADt3TgXaHDU.jpg',
#       'width': 1440,
#       'height': 1920,
#       'user': {'id': '4090645',
#        'firstName': 'Cynthia',
#        'lastName': 'H',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/ZOW23LLVS5BWLYOZ.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1582307664,
#  'tips': {'count': 0,
#   'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]},
#  'shortUrl': 'https://4sq.com/37NtNTF',
#  'timeZone': 'America/Chicago',
#  'listed': {'count': 1,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 1,
#     'items': [{'id': '5ea8663b0b782c0006b9ca0a',
#       'name': 'Go back to explore: New Orleans',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '4221931',
#        'firstName': 'JH',
#        'lastName': 'H',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/4221931_pWG4uJWg_XkoEZONUkDZq3MXcPWAbjsuprqZVSQ23sqaIilPFv5pG8FDlzvwdRYiKsalXffFJ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/jhwaholmquist/list/go-back-to-explore-new-orleans',
#       'canonicalUrl': 'https://foursquare.com/jhwaholmquist/list/go-back-to-explore-new-orleans',
#       'createdAt': 1588094523,
#       'updatedAt': 1592104767,
#       'followers': {'count': 0},
#       'listItems': {'count': 38,
#        'items': [{'id': 'v5e50195087d44900083aa068',
#          'createdAt': 1592104767}]}}]}]},
#  'hours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': []},
#  'bestPhoto': {'id': '5e6fd42412e6b900087713bf',
#   'createdAt': 1584387108,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/4090645_dECXEUO1yWMsSdx5a68hQAAUBChMN8pBADt3TgXaHDU.jpg',
#   'width': 1440,
#   'height': 1920,
#   'visibility': 'public'}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Arlight, since this restaurant has no ratings, we will look at the second one

# %% [markdown]
# #### 2. The second closest cafe -- Internet Cafe On Toulouse (78 metres)

# %%
venue_id = '4f32433619836c91c7c643c6'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Well...no ratings, let's move on

# %% [markdown]
# #### 3. The third closest cafe -- Cane Cafe (134 metres)

# %%
venue_id = '5b5274aacabcff002cd0ad56'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Nope, let's move on

# %% [markdown]
# #### 4. The fourth closest cafe -- Tony Seville's Pirates Alley Cafe & Old Absinthe House (143 metres)

# %%
venue_id = '4aeb317af964a5207abf21e3'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.7

# %% [markdown]
# Yay! Finally we got a ranking! Thank God...Since we only have one ranking so far, it is no comparison that tells how good/bad the score 7.7 stands for. So let's move on.

# %% [markdown]
# #### 5. The fifth closest cafe -- Internet Café (150 metres)

# %%
venue_id = '4ccf428f3bd6236aef748421'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Too bad...Let's move on

# %% [markdown]
# #### 6. The sixth closest cafe -- cafedumonde (152 metres)

# %%
venue_id = '4f639794e4b0777dfb9086d9'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Nope...moving on...

# %% [markdown]
# #### 7. The seventh closest cafe -- Vacherie Cafe (156 metres)

# %%
venue_id = '4e7601a4d22d80eb33729adf'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.8

# %% [markdown]
# Yay! Very excited to see another ranking score. So the ranking of this one #7-7.8 is a little bit higher than #4-7.7. Let's check more cafes.

# %% [markdown]
# #### 8. The eighth closest cafe -- Cafe Opera (165 metres)

# %%
venue_id = '5506c5a6498e18fb132e132f'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Fine. Next one!

# %% [markdown]
# #### 9. The ninth closest cafe -- Fiorella's Cafe (173 metres)

# %%
venue_id = '4efa375d9911b01dddf33d5a'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Nope. Next.

# %% [markdown]
# #### 10. The tenth closest cafe -- Jazz "N" Jazz (183 metres)

# %% [markdown]
# Okay...I am not sure why this one is counted as a cafe. It belongs to Miscellaneous Shop category. When I google it, it looks like a music store. I believe it's an error somewhere. I went back and checked the searching query and that seems correct. Maybe they provide food during small concerts? Not sure. However, consider about the main purpose of this store, it will not be recommended as a main cafe for users. So let's move on...

# %% [markdown]
# #### 11 & 12 & 13 & 14 cafe

# %% [markdown]
# 11. La Cafe (215 metres)
# 12. Cafè Dauphine (222 metres)
# 13. Cafe A'du Ma (228 metres)
# 14. Cafe Soule and The Paris Room (236 metres)
#
# As you can tell, these four cafes seem not within 200 metres, which made me run into big confusion.
#
# If they are out of searching raduis, how can they still be listed as results?
#
# If they are not, why they are further?
#
# Is there something wrong with the searching query?

# %% [markdown]
# In order to see why this happens, I went back to my reference: Learning FourSquare API with Python and re-run through the notebook. Still cannot answer these questions. But as for the project that is aiming for cafes within 200 metres. These cafes will not be considered.

# %% [markdown]
# ### Results & Discussions

# %% [markdown]
# 1. There are totally nine cafes within 200 metres of Bourbon street.
#
# 2. Among these nine cafes, seven of them have not been rated on Foursquare and two have been rated.
#
# 3. Between these two rated cafes:
#         -Tony Seville's Pirates Alley Cafe & Old Absinthe House, which is 143 metres away from Bourbon street, has a rating score of 7.7
#         -Vacherie Cafe, which is 156 metres away from Bourbon street, has a rating score of 7.8
#
# Because the rated two cafes do not have distinct differences on either distances or scores, there is not an absolute better one in these two.
#
# They both worth being recommended for visiters.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. If you prefer a rated cafe that is closer to Bourbon street, please visit Tony Seville's Pirates Alley Cafe & Old Absinthe House.
#         Address: 622 Pirates Aly (Cabildo Alley), New Orleans, LA 70116
# 2. If you prefer a rated cafe that has a higher ranking score on Foursquare, please visit Vacherie Cafe.
#         Address: 827 Toulouse St (at Dauphine St.), New Orleans, LA 70112
